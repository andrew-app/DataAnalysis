# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("datasets/avocado.csv", index_col=['Date'], parse_dates=['Date'])

state_df = df1[df1['region'] == "California" ]
s = state_df.resample('MS').AveragePrice.mean()
print (s)

s.plot()
# Out:
# Date
# 2015-01-01    1.10125
# 2015-02-01    1.13375
# 2015-03-01    1.20000
# 2015-04-01    1.30250
# 2015-05-01    1.23400
# 2015-06-01    1.35375
# 2015-07-01    1.48125
# 2015-08-01    1.54400
# 2015-09-01    1.51625
# 2015-10-01    1.50125
# 2015-11-01    1.27900
# 2015-12-01    1.14500
# 2016-01-01    1.12600
# 2016-02-01    1.10750
# 2016-03-01    1.16625
# 2016-04-01    1.15125
# 2016-05-01    1.12400
# 2016-06-01    1.27125
# 2016-07-01    1.35400
# 2016-08-01    1.29875
# 2016-09-01    1.44500
# 2016-10-01    1.79800
# 2016-11-01    1.79125
# 2016-12-01    1.30500
# 2017-01-01    1.19300
# 2017-02-01    1.13750
# 2017-03-01    1.41875
# 2017-04-01    1.43500
# 2017-05-01    1.47625
# 2017-06-01    1.45500
# 2017-07-01    1.66900
# 2017-08-01    1.91750
# 2017-09-01    1.91750
# 2017-10-01    1.82800
# 2017-11-01    1.57375
# 2017-12-01    1.41700
# 2018-01-01    1.48250
# 2018-02-01    1.38875
# 2018-03-01    1.36250
# Freq: MS, Name: AveragePrice, dtype: float64
# ...

# %%
albany_df = df[ df['region'] == "Albany" ]


albany_df.set_index("Date", inplace=True)
albany_df.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27   48.16     8696.87     8603.62       93.25          0.0
# 2015-12-20   58.33     9505.56     9408.07       97.49          0.0
# 2015-12-13  130.50     8145.35     8042.21      103.14          0.0
# 2015-12-06   72.58     5811.16     5677.40      133.76          0.0
# 2015-11-29   75.78     6183.95     5986.26      197.69          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Albany
# ...

# %%
albany_df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
albany_df = df.copy()[df["region"] == "Albany"]

albany_df.set_index("Date", inplace=True)

albany_df.sort_index(inplace=True)

# %%
albany_df
# Out:
#             Unnamed: 0  AveragePrice  Total Volume      4046       4225  \
# Date
# 2015-01-04          51          1.22      40873.28   2819.50   28287.42
# 2015-01-04          51          1.79       1373.95     57.42     153.88
# 2015-01-11          50          1.24      41195.08   1002.85   31640.34
# 2015-01-11          50          1.77       1182.56     39.00     305.12
# 2015-01-18          49          1.17      44511.28    914.14   31540.32
# ...                ...           ...           ...       ...        ...
# 2018-03-11           2          1.68       2570.52    131.67     229.56
# 2018-03-18           1          1.66       3154.45    275.89     297.96
# 2018-03-18           1          1.35     105304.65  13234.86   61037.58
# 2018-03-25           0          1.57     149396.50  16361.69  109045.03
# 2018-03-25           0          1.71       2321.82     42.95     272.41
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# ...

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
df2 = pd.read_csv("datasets/avocado.csv")
cali = pd.DataFrame()

region_df = df2.copy()[ df2['region'] == "California" ]

cali = region_df.copy()[["Date","AveragePrice"]]

M=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']



cali["Month"] = "NA"



cali.loc[cali.Date.str.contains('2015-01'), 'Month'] = M[0]
cali.loc[cali.Date.str.contains('2015-02'), 'Month'] = M[1]
cali.loc[cali.Date.str.contains('2015-03'), 'Month'] = M[2]
cali.loc[cali.Date.str.contains('2015-04'), 'Month'] = M[3]
cali.loc[cali.Date.str.contains('2015-05'), 'Month'] = M[4]
cali.loc[cali.Date.str.contains('2015-06'), 'Month'] = M[5]
cali.loc[cali.Date.str.contains('2015-07'), 'Month'] = M[6]
cali.loc[cali.Date.str.contains('2015-08'), 'Month'] = M[7]
cali.loc[cali.Date.str.contains('2015-09'), 'Month'] = M[8]
cali.loc[cali.Date.str.contains('2015-10'), 'Month'] = M[9]
cali.loc[cali.Date.str.contains('2015-11'), 'Month'] = M[10]
cali.loc[cali.Date.str.contains('2015-12'), 'Month'] = M[11]

cali.loc[cali.Date.str.contains('2016-01'), 'Month'] = M[0]
cali.loc[cali.Date.str.contains('2016-02'), 'Month'] = M[1]
cali.loc[cali.Date.str.contains('2016-03'), 'Month'] = M[2]
cali.loc[cali.Date.str.contains('2016-04'), 'Month'] = M[3]
cali.loc[cali.Date.str.contains('2016-05'), 'Month'] = M[4]
cali.loc[cali.Date.str.contains('2016-06'), 'Month'] = M[5]
cali.loc[cali.Date.str.contains('2016-07'), 'Month'] = M[6]
cali.loc[cali.Date.str.contains('2016-08'), 'Month'] = M[7]
cali.loc[cali.Date.str.contains('2016-09'), 'Month'] = M[8]
cali.loc[cali.Date.str.contains('2016-10'), 'Month'] = M[9]
cali.loc[cali.Date.str.contains('2016-11'), 'Month'] = M[10]
cali.loc[cali.Date.str.contains('2016-12'), 'Month'] = M[11]

cali.loc[cali.Date.str.contains('2017-01'), 'Month'] = M[0]
cali.loc[cali.Date.str.contains('2017-02'), 'Month'] = M[1]
cali.loc[cali.Date.str.contains('2017-03'), 'Month'] = M[2]
cali.loc[cali.Date.str.contains('2017-04'), 'Month'] = M[3]
cali.loc[cali.Date.str.contains('2017-05'), 'Month'] = M[4]
cali.loc[cali.Date.str.contains('2017-06'), 'Month'] = M[5]
cali.loc[cali.Date.str.contains('2017-07'), 'Month'] = M[6]
cali.loc[cali.Date.str.contains('2017-08'), 'Month'] = M[7]
cali.loc[cali.Date.str.contains('2017-09'), 'Month'] = M[8]
cali.loc[cali.Date.str.contains('2017-10'), 'Month'] = M[9]
cali.loc[cali.Date.str.contains('2017-11'), 'Month'] = M[10]
cali.loc[cali.Date.str.contains('2017-12'), 'Month'] = M[11]

cali.loc[cali.Date.str.contains('2018-01'), 'Month'] = M[0]
cali.loc[cali.Date.str.contains('2018-02'), 'Month'] = M[1]
cali.loc[cali.Date.str.contains('2018-03'), 'Month'] = M[2]
cali.loc[cali.Date.str.contains('2018-04'), 'Month'] = M[3]
cali.loc[cali.Date.str.contains('2018-05'), 'Month'] = M[4]
cali.loc[cali.Date.str.contains('2018-06'), 'Month'] = M[5]
cali.loc[cali.Date.str.contains('2018-07'), 'Month'] = M[6]
cali.loc[cali.Date.str.contains('2018-08'), 'Month'] = M[7]
cali.loc[cali.Date.str.contains('2018-09'), 'Month'] = M[8]
cali.loc[cali.Date.str.contains('2018-10'), 'Month'] = M[9]
cali.loc[cali.Date.str.contains('2018-11'), 'Month'] = M[10]
cali.loc[cali.Date.str.contains('2018-12'), 'Month'] = M[11]

# %%
cali.head(10)
# Out:
#            Date  AveragePrice Month
# 312  2015-12-27          0.90   Dec
# 313  2015-12-20          0.94   Dec
# 314  2015-12-13          0.87   Dec
# 315  2015-12-06          0.78   Dec
# 316  2015-11-29          0.91   Nov
# 317  2015-11-22          0.92   Nov
# 318  2015-11-15          0.83   Nov
# 319  2015-11-08          0.98   Nov
# 320  2015-11-01          0.95   Nov
# 321  2015-10-25          1.12   Oct

# %%
cali.plot.scatter(x='Month', y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='AveragePrice'>

# %%
cali.to_csv('caliprices.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-77-5d3faf384038> in <module>
# ----> 1 cali.to_csv('caliprices.csv')
#
# c:\users\andre\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# c:\users\andre\appdata\local\programs\python\python37\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     188                 encoding=self.encoding,
#     189                 errors=self.errors,
# ...

# %%
for y in M:

 x = cali.Month.str.count(y).sum()

 print(x)
    

 cali['AvgMonth'] = cali['AveragePrice'].rolling(x).mean()
# Out:
# 36
# 32
# 34
# 26
# 28
# 24
# 28
# 26
# 24
# 28
# 26
# 26

# %%
cali.plot.scatter(x='Month', y='AvgMonth')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='AvgMonth'>

# %%
cali.groupby('Month')

# %%
cali.get_group('Jan')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-d0d83df8a411> in <module>
# ----> 1 cali.get_group('Jan')
#
# c:\users\andre\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_group'
